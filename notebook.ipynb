# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# %pip install -q roboflow
import numpy as np

import torch
import os
from IPython.display import Image, clear_output
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17413, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 17413 (delta 64), reused 22 (delta 22), pack-reused 17327 (from 4)
# Receiving objects: 100% (17413/17413), 16.31 MiB | 19.33 MiB/s, done.
# Resolving deltas: 100% (11932/11932), done.
# /content/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="izGwyV2ZEfksos3MHpUs")
project = rf.workspace("my-workspace-1sedt").project("app-ml-assignment-3")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to app-ml-assignment-3-1 in yolov5pytorch:: 100%|██████████| 2346/2346 [00:00<00:00, 5662.00it/s]

# %%
import os
path=dataset.location
for item in os.listdir(path):
    print(item)
# Out:
# valid
# train
# test
# README.roboflow.txt
# README.dataset.txt
# data.yaml

# %%
# %cd /content/yolov5  # go inside yolov5 folder (if not already)
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/yolov5/app-ml-assignment-3-1/data.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#        3/49      4.38G    0.05546    0.02897    0.03469         63        640:  41% 21/51 [00:04<00:06,  4.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/49      4.38G    0.05564    0.02884    0.03487         68        640:  43% 22/51 [00:05<00:06,  4.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        3/49      4.38G    0.05587    0.02899    0.03491         78        640:  45% 23/51 [00:05<00:06,  4.29it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# %cd /content/yolov5  # go inside yolov5 folder (if not already)
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/yolov5/Stationary_Dataset-1/data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --conf 0.07 --source {dataset.location}/test/images
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/yolov5/app-ml-assignment-3-1/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.07, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/114 /content/yolov5/app-ml-assignment-3-1/test/images/11_jpg.rf.bb77783aa4b7be3cdddf50d12d935051.jpg: 640x640 1 Pencil, 1 Scale, 24.3ms
# ...

# %%
# # display inference on all test images
# import glob
# from IPython.display import Image, display
# i = 0
# for imagename in glob.glob('/content/yolov5/runs/train/exp/*.jpg'):
#   i += 1
#   if i< 27:
#     display(Image(filename = imagename))
#     print("\n\n\n")

# %% [markdown]
# Save the Training Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r runs/train/exp /content/drive/MyDrive/yolov5/

# %%
# !cp  -r /content/yolov5/runs/detect/exp3 /content/drive/MyDrive/image_result
# Out:
# cp: cannot stat '/content/yolov5/runs/detect/exp3': No such file or directory

# %% [markdown]
# # Calculate total bill for inference

# %%
# !apt-get install swig cmake libopenmpi-dev zlib1g-dev xvfb x11-utils ghostscript ffmpeg -qq #remove -qq for full output
# !pip install pyvirtualdisplay ghostscript
# Out:
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/g/ghostscript/libgs9-common_9.55.0%7edfsg1-0ubuntu5.10_all.deb  404  Not Found [IP: 91.189.91.83 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/g/ghostscript/libgs9_9.55.0%7edfsg1-0ubuntu5.10_amd64.deb  404  Not Found [IP: 91.189.91.83 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/g/ghostscript/ghostscript_9.55.0%7edfsg1-0ubuntu5.10_amd64.deb  404  Not Found [IP: 91.189.91.83 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# ...

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
import streamlit as st

# %%
# !ngrok config add-authtoken 2wPX19BE4t0WJM7RQWl8rxRtQAy_4yBk9gvnhm4scwz59p6GT
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !pkill -9 streamlit
# !pkill -9 ngrok

# %%
from pyngrok import ngrok

# !nohup streamlit run /content/app.py &
# Setup a tunnel to the streamlit port 8501
public_url = ngrok.connect(8501)
print(f"Public URL: {public_url}")
# Out:
# nohup: appending output to 'nohup.out'
# Public URL: NgrokTunnel: "https://55a2-34-125-140-243.ngrok-free.app" -> "http://localhost:8501"
